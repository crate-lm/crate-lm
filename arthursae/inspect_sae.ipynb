# %% [markdown]
# # Setup

# %% [markdown]
# ## Dependencies

# %%
import transformer_lens
from transformer_lens import HookedTransformer, utils
import torch
import numpy as np
import gradio as gr
import pprint
import json
import torch.nn as nn
import torch.nn.functional as F
from datasets import load_dataset
from huggingface_hub import HfApi
from IPython.display import HTML
from functools import partial
import tqdm.notebook as tqdm
import plotly.express as px
import pandas as pd
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
# os.environ["CUDA_VISIBLE_DEVICES"]="3"

# %%
MODEL = 'crate-3l'
MULT = 16
LAYER = 2

# %% [markdown]
# ## Defining the Autoencoder

# %%
import sae
if '6l' in MODEL:
    d_base = 768
else:
    d_base = 128
cfg = {
    "seed": 1, 
    "batch_size": 10,  # Number of samples we pass through THE LM 
    "seq_len": 1024,  # Length of each input sequence for the model
    "d_in": d_base * 4,   # Input dimension for the encoder model
    "d_sae": d_base * 4 * MULT,  # Dimensionality for the sparse autoencoder (SAE)
    "l1_lambda": 1.6e-4,
    "dataset": "-",  # Name of the dataset to use
    "dataset_args": [],  # Any additional arguments for the dataset
    "dataset_kwargs": {"split": "train", "streaming": True}, 
    "dtype": torch.float32, 
    "device": "cuda:0"
}

# import os
encoder = sae.SAE(cfg)
dir_path = f"/home/ubuntu/nanogpt4crate/arthursae/rebuttal/{MODEL.lower()}-{MULT}x/{LAYER}"
# get file path (file is the only file in the directory)
file_name = os.listdir(dir_path)[0]
path = os.path.join(dir_path, file_name)
encoder.load_from_local(path=path)
# Out:
# /home/ubuntu/nanogpt4crate/arthursae/sae/model.py:403: FutureWarning:
#
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.

# %% [markdown]
# ## Utils

# %% [markdown]
# ### Get Reconstruction Loss

# %%
def replacement_hook(mlp_post, hook, encoder):
    mlp_post[:] = encoder(mlp_post, return_mode="sae_out")
    # print("mlp_post_reconstr equal to mlp_post?", (mlp_post_reconstr == mlp_post).all())
    # print("mlp_post_reconstr:", mlp_post_reconstr)
    # print("mlp_post:", mlp_post)
    return mlp_post

def mean_ablate_hook(mlp_post, hook):
    mlp_post[:] = mlp_post.mean([0, 1])
    return mlp_post

def zero_ablate_hook(mlp_post, hook):
    mlp_post[:] = 0.
    return mlp_post

@torch.no_grad()
def get_recons_loss(num_batches=20, local_encoder=None):
    if local_encoder is None:
        local_encoder = encoder
    loss_list = []
    for i in range(num_batches):
        tokens = all_tokens[torch.randperm(len(all_tokens))[:cfg["batch_size"]]]
        loss = model(tokens, return_type="loss")
        recons_loss = model.run_with_hooks(tokens, return_type="loss", fwd_hooks=[(utils.get_act_name("post", LAYER), partial(replacement_hook, encoder=local_encoder))])
        mean_abl_loss = model.run_with_hooks(tokens, return_type="loss", fwd_hooks=[(utils.get_act_name("post", LAYER), mean_ablate_hook)])
        zero_abl_loss = model.run_with_hooks(tokens, return_type="loss", fwd_hooks=[(utils.get_act_name("post", LAYER), zero_ablate_hook)])
        loss_list.append((loss, recons_loss, zero_abl_loss))
    losses = torch.tensor(loss_list)
    loss, recons_loss, zero_abl_loss = losses.mean(0).tolist()
    
    print(f"loss: {loss:.4f}, recons_loss: {recons_loss:.4f}, zero_abl_loss: {zero_abl_loss:.4f}, mean_abl_loss: {mean_abl_loss:.4f}")
    score = ((zero_abl_loss - recons_loss)/(zero_abl_loss - loss))
    print(f"Reconstruction Score: {score:.2%}")
    # print(f"{((zero_abl_loss - mean_abl_loss)/(zero_abl_loss - loss)).item():.2%}")
    return score, loss, recons_loss, zero_abl_loss, mean_abl_loss

# %% [markdown]
# ### Get Frequencies

# %%
# Frequency
@torch.no_grad()
def get_freqs(num_batches=25, local_encoder=None):
    if local_encoder is None:
        local_encoder = encoder
    # each dimension gets a freq score
    act_freq_scores = torch.zeros(local_encoder.d_sae, dtype=torch.float32).cuda()
    total = 0
    for i in tqdm.trange(num_batches):
        tokens = all_tokens[torch.randperm(len(all_tokens))[:cfg["batch_size"]]] # subsample
        # print(tokens)
        # print("number of tokens:", len(tokens))

        _, cache = model.run_with_cache(tokens, stop_at_layer=LAYER+1, names_filter=utils.get_act_name("post", LAYER))
        mlp_acts = cache[utils.get_act_name("post", LAYER)]
        # print("shape of mlp_acts (after model):", mlp_acts.shape)
        mlp_acts = mlp_acts.reshape(-1, d_mlp)
        # overcomplete autoencoding
        # loss, x_reconstruct, **acts**, l2_loss, l1_loss
        hidden = local_encoder(mlp_acts, return_mode="hidden_post")
        # print("shape of hidden (after local_encoder):", hidden.shape)

        act_freq_scores += (hidden > 0).sum(0)

        total+=hidden.shape[0]

    print("total:", total)
    act_freq_scores /= total
    num_dead = (act_freq_scores==0).float().mean()
    print("Num dead", num_dead)
    return act_freq_scores

# %% [markdown]
# ## Visualise Feature Utils

# %%
from html import escape
import colorsys

from IPython.display import display

SPACE = "·"
NEWLINE="↩"
TAB = "→"

def create_html(strings, values, max_value=None, saturation=0.5, allow_different_length=False, return_string=False):
    # escape strings to deal with tabs, newlines, etc.
    escaped_strings = [escape(s, quote=True) for s in strings]
    processed_strings = [
        s.replace("\n", f"{NEWLINE}<br/>").replace("\t", f"{TAB}&emsp;").replace(" ", "&nbsp;")
        for s in escaped_strings
    ]

    if isinstance(values, torch.Tensor) and len(values.shape)>1:
        values = values.flatten().tolist()

    if not allow_different_length:
        assert len(processed_strings) == len(values)

    # scale values
    if max_value is None:
        max_value = max(max(values), -min(values))+1e-3
    scaled_values = [v / max_value * saturation for v in values]

    # create html
    html = ""
    for i, s in enumerate(processed_strings):
        if i<len(scaled_values):
            v = scaled_values[i]
        else:
            v = 0
        if v < 0:
            hue = 0  # hue for red in HSV
        else:
            hue = 0.66  # hue for blue in HSV
        rgb_color = colorsys.hsv_to_rgb(
            hue, v, 1
        )  # hsv color with hue 0.66 (blue), saturation as v, value 1
        hex_color = "#%02x%02x%02x" % (
            int(rgb_color[0] * 255),
            int(rgb_color[1] * 255),
            int(rgb_color[2] * 255),
        )
        html += f'<span style="background-color: {hex_color}; border: 1px solid lightgray; font-size: 16px; border-radius: 3px;">{s}</span>'
    if return_string:
        return html
    else:
        display(HTML(html))

def basic_feature_vis(text, feature_index, max_val=0):
    feature_in = encoder.W_enc[:, feature_index]
    feature_bias = encoder.b_enc[feature_index]
    _, cache = model.run_with_cache(text, stop_at_layer=LAYER+1, names_filter=utils.get_act_name("post", 0))
    mlp_acts = cache[utils.get_act_name("post", 0)][0]
    feature_acts = F.relu((mlp_acts - encoder.b_dec) @ feature_in + feature_bias)
    if max_val==0:
        max_val = max(1e-7, feature_acts.max().item())
        # print(max_val)
    # if min_val==0:
    #     min_val = min(-1e-7, feature_acts.min().item())
    return basic_token_vis_make_str(text, feature_acts, max_val)
def basic_token_vis_make_str(strings, values, max_val=None):
    if not isinstance(strings, list):
        strings = model.to_str_tokens(strings)
    values = utils.to_numpy(values)
    if max_val is None:
        max_val = values.max()
    # if min_val is None:
    #     min_val = values.min()
    header_string = f"<h4>Max Range <b>{values.max():.4f}</b> Min Range: <b>{values.min():.4f}</b></h4>"
    header_string += f"<h4>Set Max Range <b>{max_val:.4f}</b></h4>"
    # values[values>0] = values[values>0]/ma|x_val
    # values[values<0] = values[values<0]/abs(min_val)
    body_string = create_html(strings, values, max_value=max_val, return_string=True)
    return header_string + body_string
# display(HTML(basic_token_vis_make_str(tokens[0, :10], mlp_acts[0, :10, 7], 0.1)))
# # %%
# The `with gr.Blocks() as demo:` syntax just creates a variable called demo containing all these components
import gradio as gr
try:
    demos[0].close()
except:
    pass
demos = [None]
def make_feature_vis_gradio(feature_id, starting_text=None, batch=None, pos=None):
    if starting_text is None:
        starting_text = model.to_string(all_tokens[batch, 1:pos+1])
    try:
        demos[0].close()
    except:
        pass
    with gr.Blocks() as demo:
        gr.HTML(value=f"Hacky Interactive Neuroscope for gelu-1l")
        # The input elements
        with gr.Row():
            with gr.Column():
                text = gr.Textbox(label="Text", value=starting_text)
                # Precision=0 makes it an int, otherwise it's a float
                # Value sets the initial default value
                feature_index = gr.Number(
                    label="Feature Index", value=feature_id, precision=0
                )
                # # If empty, these two map to None
                max_val = gr.Number(label="Max Value", value=None)
                # min_val = gr.Number(label="Min Value", value=None)
                inputs = [text, feature_index, max_val]
        with gr.Row():
            with gr.Column():
                # The output element
                out = gr.HTML(label="Neuron Acts", value=basic_feature_vis(starting_text, feature_id))
        for inp in inputs:
            inp.change(basic_feature_vis, inputs, out)
    demo.launch(share=True)
    demos[0] = demo

# %% [markdown]
# ### Inspecting Top Logits

# %%
SPACE = "·"
NEWLINE="↩"
TAB = "→"
def process_token(s):
    if isinstance(s, torch.Tensor):
        s = s.item()
    if isinstance(s, np.int64):
        s = s.item()
    if isinstance(s, int):
        s = model.to_string(s)
    s = s.replace(" ", SPACE)
    s = s.replace("\n", NEWLINE+"\n")
    s = s.replace("\t", TAB)
    return s

def process_tokens(l):
    if isinstance(l, str):
        l = model.to_str_tokens(l)
    elif isinstance(l, torch.Tensor) and len(l.shape)>1:
        l = l.squeeze(0)
    return [process_token(s) for s in l]

def process_tokens_index(l):
    if isinstance(l, str):
        l = model.to_str_tokens(l)
    elif isinstance(l, torch.Tensor) and len(l.shape)>1:
        l = l.squeeze(0)
    return [f"{process_token(s)}/{i}" for i,s in enumerate(l)]

def create_vocab_df(logit_vec, make_probs=False, full_vocab=None):
    if full_vocab is None:
        full_vocab = process_tokens(model.to_str_tokens(torch.arange(model.cfg.d_vocab)))
    vocab_df = pd.DataFrame({"token": full_vocab, "logit": utils.to_numpy(logit_vec)})
    if make_probs:
        vocab_df["log_prob"] = utils.to_numpy(logit_vec.log_softmax(dim=-1))
        vocab_df["prob"] = utils.to_numpy(logit_vec.softmax(dim=-1))
    return vocab_df.sort_values("logit", ascending=False)

# %% [markdown]
# ### Make Token DataFrame

# %%
def list_flatten(nested_list):
    return [x for y in nested_list for x in y]
def make_token_df(tokens, len_prefix=10, len_suffix=10):
    str_tokens = [process_tokens(model.to_str_tokens(t)) for t in tokens]
    unique_token = [[f"{s}/{i}" for i, s in enumerate(str_tok)] for str_tok in str_tokens]

    context = []
    batch = []
    pos = []
    label = []
    for b in range(tokens.shape[0]):
        # context.append([])
        # batch.append([])
        # pos.append([])
        # label.append([])
        for p in range(tokens.shape[1]):
            prefix = "".join(str_tokens[b][max(0, p-len_prefix):p])
            if p==tokens.shape[1]-1:
                suffix = ""
            else:
                suffix = "".join(str_tokens[b][p+1:min(tokens.shape[1]-1, p+1+len_suffix)])
            current = str_tokens[b][p]
            context.append(f"{prefix}|{current}|{suffix}")
            batch.append(b)
            pos.append(p)
            label.append(f"{b}/{p}")
    # print(len(batch), len(pos), len(context), len(label))
    return pd.DataFrame(dict(
        str_tokens=list_flatten(str_tokens),
        unique_token=list_flatten(unique_token),
        context=context,
        batch=batch,
        pos=pos,
        label=label,
    ))

# %% [markdown]
# ## Loading the Model

# %%
if 'crate' in MODEL:
    model = HookedTransformer.from_pretrained(MODEL, fold_ln=False).to(cfg["dtype"])
else:
    model = HookedTransformer.from_pretrained(MODEL).to(cfg["dtype"])
n_layers = model.cfg.n_layers
d_model = model.cfg.d_model
n_heads = model.cfg.n_heads
d_head = model.cfg.d_head
d_mlp = model.cfg.d_mlp
d_vocab = model.cfg.d_vocab
# Out:
# architecture crate
# entering crate
# loading model crate-3l
# loading model /home/ubuntu/nanogpt4crate/out/ckpt-crate-3l-overparam.pt
# entering nanogpt
# dict_keys(['transformer.wte.weight', 'transformer.wpe.weight', 'transformer.h.0.prenorm_1.weight', 'transformer.h.0.prenorm_1.bias', 'transformer.h.0.attn.bias', 'transformer.h.0.attn.c_attn.weight', 'transformer.h.0.attn.c_proj.weight', 'transformer.h.0.attn.c_proj.bias', 'transformer.h.0.prenorm_2.weight', 'transformer.h.0.prenorm_2.bias', 'transformer.h.0.ista.weight', 'transformer.h.1.prenorm_1.weight', 'transformer.h.1.prenorm_1.bias', 'transformer.h.1.attn.bias', 'transformer.h.1.attn.c_attn.weight', 'transformer.h.1.attn.c_proj.weight', 'transformer.h.1.attn.c_proj.bias', 'transformer.h.1.prenorm_2.weight', 'transformer.h.1.prenorm_2.bias', 'transformer.h.1.ista.weight', 'transformer.h.2.prenorm_1.weight', 'transformer.h.2.prenorm_1.bias', 'transformer.h.2.attn.bias', 'transformer.h.2.attn.c_attn.weight', 'transformer.h.2.attn.c_proj.weight', 'transformer.h.2.attn.c_proj.bias', 'transformer.h.2.prenorm_2.weight', 'transformer.h.2.prenorm_2.bias', 'transformer.h.2.ista.weight', 'transformer.ln_f.weight', 'transformer.ln_f.bias', 'lm_head.weight'])
# HookedTransformerConfig:
# {'act_fn': 'relu',
#  'attention_dir': 'causal',
#  'attn_only': False,
#  'attn_types': None,
#  'checkpoint_index': None,
#  'checkpoint_label_type': None,
#  'checkpoint_value': None,
#  'd_head': 32,
#  'd_mlp': 512,
#  'd_model': 128,
#  'd_vocab': 50304,
#  'd_vocab_out': 50304,
#  'default_prepend_bos': True,
#  'device': device(type='cuda'),
#  'dtype': torch.float32,
#  'eps': 1e-05,
#  'final_rms': False,
#  'from_checkpoint': False,
#  'gated_mlp': False,
#  'init_mode': 'gpt2',
#  'init_weights': False,
#  'initializer_range': 0.07071067811865475,
#  'model_name': 'crate-3l',
#  'n_ctx': 1024,
#  'n_devices': 1,
#  'n_heads': 4,
#  'n_key_value_heads': None,
#  'n_layers': 3,
#  'n_params': 589824,
#  'normalization_type': 'LN',
#  'original_architecture': 'CrateForCausalLM',
#  'parallel_attn_mlp': False,
#  'positional_embedding_type': 'standard',
#  'post_embedding_ln': False,
#  'rotary_adjacent_pairs': False,
#  'rotary_base': 10000,
#  'rotary_dim': None,
#  'scale_attn_by_inverse_layer_idx': False,
#  'seed': None,
#  'tokenizer_name': 'crate-3l',
#  'tokenizer_prepends_bos': None,
#  'trust_remote_code': False,
#  'use_attn_in': False,
#  'use_attn_result': False,
#  'use_attn_scale': True,
#  'use_hook_mlp_in': False,
#  'use_hook_tokens': False,
#  'use_local_attn': False,
#  'use_split_qkv_input': False,
#  'window_size': None}
# /home/ubuntu/nanogpt4crate/TransformerLens/transformer_lens/loading_from_pretrained.py:1599: FutureWarning:
#
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# Loaded pretrained model crate-3l into HookedTransformer
# Changing model dtype to torch.float32

# %%
tokens = "Beijing is the capital of"
input_ids = model.tokenizer.encode(tokens, return_tensors="pt").cuda()
create_vocab_df(model(input_ids)[0][-1], make_probs=True).head(20).style.background_gradient("coolwarm")
# Out:
# <style type="text/css">
# #T_e3187_row0_col1, #T_e3187_row0_col2, #T_e3187_row0_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e3187_row1_col1, #T_e3187_row1_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_e3187_row1_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_e3187_row2_col1, #T_e3187_row2_col2 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_e3187_row2_col3 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_e3187_row3_col1, #T_e3187_row3_col2 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_e3187_row3_col3, #T_e3187_row13_col1, #T_e3187_row13_col2, #T_e3187_row14_col1, #T_e3187_row14_col2, #T_e3187_row15_col1, #T_e3187_row15_col2 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_e3187_row4_col1, #T_e3187_row4_col2 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_e3187_row4_col3, #T_e3187_row5_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_e3187_row5_col1, #T_e3187_row5_col2 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_e3187_row6_col1, #T_e3187_row6_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_e3187_row6_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_e3187_row7_col1, #T_e3187_row7_col2 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_e3187_row7_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_e3187_row8_col1, #T_e3187_row8_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_e3187_row8_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_e3187_row9_col1, #T_e3187_row9_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_e3187_row9_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_e3187_row10_col1, #T_e3187_row10_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_e3187_row10_col3, #T_e3187_row11_col3 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_e3187_row11_col1, #T_e3187_row11_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_e3187_row12_col1, #T_e3187_row12_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_e3187_row12_col3, #T_e3187_row13_col3, #T_e3187_row14_col3, #T_e3187_row15_col3, #T_e3187_row16_col3, #T_e3187_row17_col3, #T_e3187_row18_col3, #T_e3187_row19_col1, #T_e3187_row19_col2, #T_e3187_row19_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e3187_row16_col1, #T_e3187_row16_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_e3187_row17_col1, #T_e3187_row17_col2 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_e3187_row18_col1, #T_e3187_row18_col2 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e3187">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3187_level0_col0" class="col_heading level0 col0" >token</th>
#       <th id="T_e3187_level0_col1" class="col_heading level0 col1" >logit</th>
#       <th id="T_e3187_level0_col2" class="col_heading level0 col2" >log_prob</th>
#       <th id="T_e3187_level0_col3" class="col_heading level0 col3" >prob</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3187_level0_row0" class="row_heading level0 row0" >262</th>
#       <td id="T_e3187_row0_col0" class="data row0 col0" >·the</td>
#       <td id="T_e3187_row0_col1" class="data row0 col1" >13.381050</td>
#       <td id="T_e3187_row0_col2" class="data row0 col2" >-1.301797</td>
#       <td id="T_e3187_row0_col3" class="data row0 col3" >0.272043</td>
#     </tr>
#     <tr>
#       <th id="T_e3187_level0_row1" class="row_heading level0 row1" >2807</th>
#       <td id="T_e3187_row1_col0" class="data row1 col0" >·China</td>
#       <td id="T_e3187_row1_col1" class="data row1 col1" >11.085363</td>
#       <td id="T_e3187_row1_col2" class="data row1 col2" >-3.597484</td>
#       <td id="T_e3187_row1_col3" class="data row1 col3" >0.027393</td>
#     </tr>
#     <tr>
#       <th id="T_e3187_level0_row2" class="row_heading level0 row2" >257</th>
#       <td id="T_e3187_row2_col0" class="data row2 col0" >·a</td>
#       <td id="T_e3187_row2_col1" class="data row2 col1" >10.666135</td>
#       <td id="T_e3187_row2_col2" class="data row2 col2" >-4.016712</td>
#       <td id="T_e3187_row2_col3" class="data row2 col3" >0.018012</td>
#     </tr>
#     <tr>
#       <th id="T_e3187_level0_row3" class="row_heading level0 row3" >3794</th>
#       <td id="T_e3187_row3_col0" class="data row3 col0" >·India</td>
#       <td id="T_e3187_row3_col1" class="data row3 col1" >10.477721</td>
#       <td id="T_e3187_row3_col2" class="data row3 col2" >-4.205126</td>
#       <td id="T_e3187_row3_col3" class="data row3 col3" >0.014919</td>
#     </tr>
#     <tr>
#       <th id="T_e3187_level0_row4" class="row_heading level0 row4" >2253</th>
#       <td id="T_e3187_row4_col0" class="data row4 col0" >·America</td>
#       <td id="T_e3187_row4_col1" class="data row4 col1" >10.265337</td>
#       <td id="T_e3187_row4_col2" class="data row4 col2" >-4.417510</td>
#       <td id="T_e3187_row4_col3" class="data row4 col3" >0.012064</td>
#     </tr>
#     <tr>
#       <th id="T_e3187_level0_row5" class="row_heading level0 row5" >674</th>
#       <td id="T_e3187_row5_col0" class="data row5 col0" >·our</td>
#       <td id="T_e3187_row5_col1" class="data row5 col1" >10.247410</td>
#       <td id="T_e3187_row5_col2" class="data row5 col2" >-4.435437</td>
#       <td id="T_e3187_row5_col3" class="data row5 col3" >0.011850</td>
#     </tr>
#     <tr>
#       <th id="T_e3187_level0_row6" class="row_heading level0 row6" >428</th>
#       <td id="T_e3187_row6_col0" class="data row6 col0" >·this</td>
#       <td id="T_e3187_row6_col1" class="data row6 col1" >10.179630</td>
#       <td id="T_e3187_row6_col2" class="data row6 col2" >-4.503217</td>
#       <td id="T_e3187_row6_col3" class="data row6 col3" >0.011073</td>
#     </tr>
#     <tr>
#       <th id="T_e3187_level0_row7" class="row_heading level0 row7" >663</th>
#       <td id="T_e3187_row7_col0" class="data row7 col0" >·its</td>
#       <td id="T_e3187_row7_col1" class="data row7 col1" >10.093251</td>
#       <td id="T_e3187_row7_col2" class="data row7 col2" >-4.589596</td>
#       <td id="T_e3187_row7_col3" class="data row7 col3" >0.010157</td>
#     </tr>
#     <tr>
#       <th id="T_e3187_level0_row8" class="row_heading level0 row8" >7595</th>
#       <td id="T_e3187_row8_col0" class="data row8 col0" >·Brazil</td>
#       <td id="T_e3187_row8_col1" class="data row8 col1" >9.771369</td>
#       <td id="T_e3187_row8_col2" class="data row8 col2" >-4.911478</td>
#       <td id="T_e3187_row8_col3" class="data row8 col3" >0.007362</td>
#     </tr>
#     <tr>
#       <th id="T_e3187_level0_row9" class="row_heading level0 row9" >198</th>
#       <td id="T_e3187_row9_col0" class="data row9 col0" >↩
# </td>
#       <td id="T_e3187_row9_col1" class="data row9 col1" >9.603951</td>
#       <td id="T_e3187_row9_col2" class="data row9 col2" >-5.078897</td>
#       <td id="T_e3187_row9_col3" class="data row9 col3" >0.006227</td>
#     </tr>
#     <tr>
#       <th id="T_e3187_level0_row10" class="row_heading level0 row10" >3442</th>
#       <td id="T_e3187_row10_col0" class="data row10 col0" >·California</td>
#       <td id="T_e3187_row10_col1" class="data row10 col1" >9.437201</td>
#       <td id="T_e3187_row10_col2" class="data row10 col2" >-5.245646</td>
#       <td id="T_e3187_row10_col3" class="data row10 col3" >0.005270</td>
#     </tr>
#     <tr>
#       <th id="T_e3187_level0_row11" class="row_heading level0 row11" >5828</th>
#       <td id="T_e3187_row11_col0" class="data row11 col0" >·Mexico</td>
#       <td id="T_e3187_row11_col1" class="data row11 col1" >9.397912</td>
#       <td id="T_e3187_row11_col2" class="data row11 col2" >-5.284935</td>
#       <td id="T_e3187_row11_col3" class="data row11 col3" >0.005067</td>
#     </tr>
#     <tr>
#       <th id="T_e3187_level0_row12" class="row_heading level0 row12" >5478</th>
#       <td id="T_e3187_row12_col0" class="data row12 col0" >·Africa</td>
#       <td id="T_e3187_row12_col1" class="data row12 col1" >9.340277</td>
#       <td id="T_e3187_row12_col2" class="data row12 col2" >-5.342570</td>
#       <td id="T_e3187_row12_col3" class="data row12 col3" >0.004784</td>
#     </tr>
#     <tr>
#       <th id="T_e3187_level0

# %%
tokens = "When Mary and John went to the store, John gave a drink to"
input_ids = model.tokenizer.encode(tokens, return_tensors="pt").cuda()
create_vocab_df(model(input_ids)[0][-1], make_probs=True).head(20).style.background_gradient("coolwarm")
# Out:
# <style type="text/css">
# #T_06c65_row0_col1, #T_06c65_row0_col2, #T_06c65_row0_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_06c65_row1_col1, #T_06c65_row1_col2 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_06c65_row1_col3 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_06c65_row2_col1, #T_06c65_row2_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_06c65_row2_col3, #T_06c65_row9_col1, #T_06c65_row9_col2, #T_06c65_row10_col1, #T_06c65_row10_col2 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_06c65_row3_col1, #T_06c65_row3_col2 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_06c65_row3_col3 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_06c65_row4_col1, #T_06c65_row4_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_06c65_row4_col3, #T_06c65_row15_col1, #T_06c65_row15_col2 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_06c65_row5_col1, #T_06c65_row5_col2 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_06c65_row5_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_06c65_row6_col1, #T_06c65_row6_col2 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_06c65_row6_col3 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_06c65_row7_col1, #T_06c65_row7_col2 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_06c65_row7_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_06c65_row8_col1, #T_06c65_row8_col2 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_06c65_row8_col3, #T_06c65_row17_col1, #T_06c65_row17_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_06c65_row9_col3, #T_06c65_row10_col3, #T_06c65_row11_col3, #T_06c65_row12_col3, #T_06c65_row13_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_06c65_row11_col1, #T_06c65_row11_col2, #T_06c65_row12_col1, #T_06c65_row12_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_06c65_row13_col1, #T_06c65_row13_col2 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_06c65_row14_col1, #T_06c65_row14_col2 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_06c65_row14_col3, #T_06c65_row15_col3, #T_06c65_row16_col3 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_06c65_row16_col1, #T_06c65_row16_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_06c65_row17_col3, #T_06c65_row18_col3, #T_06c65_row19_col1, #T_06c65_row19_col2, #T_06c65_row19_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_06c65_row18_col1, #T_06c65_row18_col2 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_06c65">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06c65_level0_col0" class="col_heading level0 col0" >token</th>
#       <th id="T_06c65_level0_col1" class="col_heading level0 col1" >logit</th>
#       <th id="T_06c65_level0_col2" class="col_heading level0 col2" >log_prob</th>
#       <th id="T_06c65_level0_col3" class="col_heading level0 col3" >prob</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06c65_level0_row0" class="row_heading level0 row0" >262</th>
#       <td id="T_06c65_row0_col0" class="data row0 col0" >·the</td>
#       <td id="T_06c65_row0_col1" class="data row0 col1" >13.737627</td>
#       <td id="T_06c65_row0_col2" class="data row0 col2" >-1.493005</td>
#       <td id="T_06c65_row0_col3" class="data row0 col3" >0.224696</td>
#     </tr>
#     <tr>
#       <th id="T_06c65_level0_row1" class="row_heading level0 row1" >257</th>
#       <td id="T_06c65_row1_col0" class="data row1 col0" >·a</td>
#       <td id="T_06c65_row1_col1" class="data row1 col1" >12.071457</td>
#       <td id="T_06c65_row1_col2" class="data row1 col2" >-3.159175</td>
#       <td id="T_06c65_row1_col3" class="data row1 col3" >0.042461</td>
#     </tr>
#     <tr>
#       <th id="T_06c65_level0_row2" class="row_heading level0 row2" >465</th>
#       <td id="T_06c65_row2_col0" class="data row2 col0" >·his</td>
#       <td id="T_06c65_row2_col1" class="data row2 col1" >11.751668</td>
#       <td id="T_06c65_row2_col2" class="data row2 col2" >-3.478964</td>
#       <td id="T_06c65_row2_col3" class="data row2 col3" >0.030839</td>
#     </tr>
#     <tr>
#       <th id="T_06c65_level0_row3" class="row_heading level0 row3" >683</th>
#       <td id="T_06c65_row3_col0" class="data row3 col0" >·him</td>
#       <td id="T_06c65_row3_col1" class="data row3 col1" >11.496007</td>
#       <td id="T_06c65_row3_col2" class="data row3 col2" >-3.734625</td>
#       <td id="T_06c65_row3_col3" class="data row3 col3" >0.023882</td>
#     </tr>
#     <tr>
#       <th id="T_06c65_level0_row4" class="row_heading level0 row4" >607</th>
#       <td id="T_06c65_row4_col0" class="data row4 col0" >·her</td>
#       <td id="T_06c65_row4_col1" class="data row4 col1" >11.386432</td>
#       <td id="T_06c65_row4_col2" class="data row4 col2" >-3.844200</td>
#       <td id="T_06c65_row4_col3" class="data row4 col3" >0.021404</td>
#     </tr>
#     <tr>
#       <th id="T_06c65_level0_row5" class="row_heading level0 row5" >307</th>
#       <td id="T_06c65_row5_col0" class="data row5 col0" >·be</td>
#       <td id="T_06c65_row5_col1" class="data row5 col1" >11.196205</td>
#       <td id="T_06c65_row5_col2" class="data row5 col2" >-4.034427</td>
#       <td id="T_06c65_row5_col3" class="data row5 col3" >0.017696</td>
#     </tr>
#     <tr>
#       <th id="T_06c65_level0_row6" class="row_heading level0 row6" >502</th>
#       <td id="T_06c65_row6_col0" class="data row6 col0" >·me</td>
#       <td id="T_06c65_row6_col1" class="data row6 col1" >11.037497</td>
#       <td id="T_06c65_row6_col2" class="data row6 col2" >-4.193135</td>
#       <td id="T_06c65_row6_col3" class="data row6 col3" >0.015099</td>
#     </tr>
#     <tr>
#       <th id="T_06c65_level0_row7" class="row_heading level0 row7" >616</th>
#       <td id="T_06c65_row7_col0" class="data row7 col0" >·my</td>
#       <td id="T_06c65_row7_col1" class="data row7 col1" >10.655001</td>
#       <td id="T_06c65_row7_col2" class="data row7 col2" >-4.575631</td>
#       <td id="T_06c65_row7_col3" class="data row7 col3" >0.010300</td>
#     </tr>
#     <tr>
#       <th id="T_06c65_level0_row8" class="row_heading level0 row8" >651</th>
#       <td id="T_06c65_row8_col0" class="data row8 col0" >·get</td>
#       <td id="T_06c65_row8_col1" class="data row8 col1" >10.532378</td>
#       <td id="T_06c65_row8_col2" class="data row8 col2" >-4.698254</td>
#       <td id="T_06c65_row8_col3" class="data row8 col3" >0.009111</td>
#     </tr>
#     <tr>
#       <th id="T_06c65_level0_row9" class="row_heading level0 row9" >467</th>
#       <td id="T_06c65_row9_col0" class="data row9 col0" >·go</td>
#       <td id="T_06c65_row9_col1" class="data row9 col1" >10.144191</td>
#       <td id="T_06c65_row9_col2" class="data row9 col2" >-5.086441</td>
#       <td id="T_06c65_row9_col3" class="data row9 col3" >0.006180</td>
#     </tr>
#     <tr>
#       <th id="T_06c65_level0_row10" class="row_heading level0 row10" >606</th>
#       <td id="T_06c65_row10_col0" class="data row10 col0" >·them</td>
#       <td id="T_06c65_row10_col1" class="data row10 col1" >10.134096</td>
#       <td id="T_06c65_row10_col2" class="data row10 col2" >-5.096536</td>
#       <td id="T_06c65_row10_col3" class="data row10 col3" >0.006118</td>
#     </tr>
#     <tr>
#       <th id="T_06c65_level0_row11" class="row_heading level0 row11" >766</th>
#       <td id="T_06c65_row11_col0" class="data row11 col0" >·see</td>
#       <td id="T_06c65_row11_col1" class="data row11 col1" >10.084421</td>
#       <td id="T_06c65_row11_col2" class="data row11 col2" >-5.146211</td>
#       <td id="T_06c65_row11_col3" class="data row11 col3" >0.005821</td>
#     </tr>
#     <tr>
#       <th id="T_06c65_level0_row12" class="row_heading level0 row12" >340</th>
#       <td id="T_06c65_row12_col0" class="data row12 col0" >·it</td>
#       <td id="T_06c65_row12_col1" class="data row12 col1" >10.079993</td>
#       <td id="T_06c65_row12_col2" class="data row12 col2" >-5.150639</td>
#       <td id="T_06c65_row12_col3" class="data row12 col3" >0.005796</td>
#     </tr>
#     <tr>
#       <th id="T_06c65_level0_row13" class="row_heading level0 row13" >511</th>
#       <td id="T_06c65_row13_

# %%
print(model.generate("I like to go to school because"))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# I like to go to school because my parents were volunteering as a really significant pair of

# %% [markdown]
# ## Loading Data

# %%
data = np.memmap('/home/ubuntu/nanogpt4crate/data/pile/val.bin', dtype=np.uint16, mode='r')
end_index = int(len(data) // 1024 * 1024)
print(end_index)
data = torch.from_numpy((data).astype(np.int64))[:end_index]
all_tokens = data.reshape(-1, cfg["seq_len"]).cuda()
print("Number of all tokens:", len(all_tokens))
# Out:
# 294434816
# Number of all tokens: 287534

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Using the Autoencoder

# %% [markdown]
# We run the model and replace the MLP activations with those reconstructed from the autoencoder, and get 91% loss recovered

# %%
# while True:
score, loss, recons_loss, zero_abl_loss, mean_abl_loss = get_recons_loss(num_batches=30, local_encoder=encoder)
    # if round(score, 2) == 3.45:
    #     break
# Out:
# loss: 3.5049, recons_loss: 3.7706, zero_abl_loss: 9.2351, mean_abl_loss: 11.1273
# Reconstruction Score: 95.36%

# %% [markdown]
# ## Rare Features Are All The Same

# %% [markdown]
# For each feature we can get the frequency at which it's non-zero (per token, averaged across a bunch of batches), and plot a histogram

# %%
freqs = get_freqs(num_batches = 20, local_encoder = encoder)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# total: 204800
# Num dead tensor(0.0010, device='cuda:0')

# %%
# Add 1e-6.5 so that dead features show up as log_freq -6.5
log_freq = (freqs + 10**-6.5).log10()
px.histogram(utils.to_numpy(log_freq), title="Log Frequency of Features", histnorm='percent')
# Out:
# <div>                            <div id="d7ff51b8-a36d-4247-bcce-648868130390" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7ff51b8-a36d-4247-bcce-648868130390")) {                    Plotly.newPlot(                        "d7ff51b8-a36d-4247-bcce-648868130390",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"percent","hovertemplate":"variable=0\u003cbr\u003evalue=%{x}\u003cbr\u003epercent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"x":[-2.2460997,-2.2593813,-2.9291964,-2.4432356,-2.2408988,-1.6615024,-2.9401424,-2.4071205,-2.7157624,-2.4775045,-2.1983683,-2.0348535,-2.8609812,-1.6179491,-1.7951828,-2.3522577,-2.464953,-2.4164245,-2.0316482,-2.439136,-1.9966067,-1.6328057,-2.0606503,-2.056042,-1.8368129,-1.9734586,-2.3363283,-2.2095606,-2.9475963,-2.2256596,-2.117909,-2.4845655,-3.56264,-1.8754753,-2.2536392,-2.4293382,-6.5000005,-1.8223474,-1.4282329,-2.097795,-1.6200659,-2.4631011,-2.3465686,-2.4203143,-2.560001,-2.7525437,-1.7460649,-2.0785716,-1.9720646,-1.8541956,-1.8120464,-2.2959433,-1.5546129,-2.4065795,-2.392218,-2.3390973,-2.2357595,-2.5607717,-1.94025,-2.9668105,-2.3494039,-1.8778698,-2.7940485,-2.1590219,-2.211627,-2.2524998,-1.9139003,-2.0735188,-2.2648096,-2.4503546,-2.4479685,-2.1584105,-2.887978,-2.5646455,-2.261312,-2.097795,-2.1689203,-2.6364095,-1.9637922,-1.8257413,-1.7354422,-2.4270644,-1.646494,-1.7498631,-2.5994682,-1.87803,-2.1761765,-1.6176852,-1.94733,-2.6131732,-2.8443663,-2.4054992,-1.5381241,-2.23649,-2.9952238,-2.2472222,-2.3475115,-2.3614209,-1.8593802,-2.0353131,-1.9341942,-3.0324285,-2.9063857,-2.176495,-1.6417282,-1.67917,-2.4208727,-2.7862012,-2.093566,-1.8604553,-2.814311,-2.5821128,-2.224947,-3.0534961,-2.4054992,-1.9007106,-2.6300302,-2.0572498,-2.413118,-2.3788235,-1.9665322,-1.6515977,-1.9058019,-1.9657476,-1.6316237,-2.3932657,-2.012681,-2.5788844,-1.874045,-2.9328144,-2.4631011,-2.133198,-2.491086,-2.4028103,-2.605411,-2.0956752,-1.938406,-2.130326,-2.4775045,-2.2807043,-1.8278762,-2.2245913,-1.7355576,-2.0111554,-1.8723029,-2.1187446,-2.0665421,-2.245353,-3.7308068,-2.3849542,-2.6237433,-2.2888749,-2.352735,-2.5623171,-2.5456133,-1.8596871,-2.515405,-1.8108103,-2.6088436,-2.8170853,-2.423114,-2.111283,-2.3027024,-2.5986257,-1.8973491,-2.184204,-2.8458507,-2.252121,-2.5508587,-1.8099879,-2.9628992,-2.6542122,-1.7463014,-2.2913566,-2.6747773,-2.5119448,-1.9369365,-1.9897182,-2.6097062,-1.7970394,-1.8277335,-1.7116581,-2.7360673,-2.3372493,-2.4533558,-2.0059645,-2.281109,-1.8721449,-2.7465875,-1.8015813,-2.2361245,-1.9075122,-2.1559744,-2.0808644,-2.247597,-2.2984655,-3.0101595,-1.9118181,-2.6318433,-2.3570561,-1.8975167,-2.6777961,-2.049576,-2.340953,-3.0463593,-2.541167,-2.4225526,-2.9401424,-2.1976993,-2.0594327,-2.7862012,-1.8544987,-2.5463586,-1.9710714,-2.0844557,-2.13291,-2.242008,-2.2487237,-1.6302638,-2.097795,-2.5133257,-1.9872402,-2.936463,-2.2597666,-2.1658027,-2.685951,-2.2295995,-2.528811,-1.8940136,-1.4823439,-2.2683356,-2.4248028,-2.5772789,-2.9727445,-2.0063949,-2.7598011,-2.7525437,-2.3121715,-2.2386887,-2.0640776,-2.9185193,-2.2321253,-1.8584608,-1.8022532,-1.750579,-2.044378,-2.0208359,-2.1028714,-1.7227149,-2.2675495,-2.46993,-1.3304605,-2.9115443,-2.13522,-2.1803324,-1.8522295,-1.6744347,-2.52738,-1.8742036,-3.1152513,-2.7721727,-1.821503,-2.3937905,-2.1297538,-1.7967737,-2.040636,-1.7202581,-3.2392097,-2.116243,-2.4236763,-2.8863428,-2.2963626,-2.00532,-2.0441432,-1.7650261,-2.2807043,-2.1460664,-2.707034,-1.8738863,-1.5798972,-2.4904296,-2.4248028,-2.2460997,-2.21301,-2.4397192,-2.056042,-1.7800983,-2.3227422,-1.5631369,-2.0366955,-2.6818545,-2.4588103,-2.596946 ...

# %% [markdown]
# We see that it's clearly bimodal! Let's define rare features as those with freq < 1e-4, and look at the cosine sim of each feature with the average rare feature - we see that almost all rare features correspond to this feature!

# %% [markdown]
# 这个(2048,)的稀疏特征条很有价值

# %%
is_rare = freqs < 1e-5
# W_enc is the dictionary
rare_enc = encoder.W_enc[:, is_rare]
rare_mean = rare_enc.mean(-1)
cos_sim = utils.to_numpy(rare_mean @ encoder.W_enc / rare_mean.norm() / encoder.W_enc.norm(dim=0))
px.histogram(cos_sim, title="Cosine Sim with Ave Rare Feature", color=utils.to_numpy(is_rare), labels={"color": "is_rare", "count": "percent", "value": "cosine_sim"}, marginal="box", histnorm="percent", barmode='overlay')
# Out:
# <div>                            <div id="19bdf518-57b2-4bdb-a721-83482142b836" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19bdf518-57b2-4bdb-a721-83482142b836")) {                    Plotly.newPlot(                        "19bdf518-57b2-4bdb-a721-83482142b836",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"percent","hovertemplate":"is_rare=False\u003cbr\u003ecosine_sim=%{x}\u003cbr\u003epercent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"False","offsetgroup":"False","orientation":"v","showlegend":true,"x":[0.0012683149,0.05893377,0.012539133,0.024415335,-0.087862365,-0.021038555,0.098773666,-0.014592284,-0.0022800767,0.041779447,0.12271382,-0.0079805255,-0.00046097353,-0.018423945,0.03259985,-0.0155362245,0.09557195,-0.029377129,-0.06462425,-0.0027538252,0.06597196,0.015482887,0.081899926,-0.09101637,-0.05734571,0.07269396,-0.032971412,0.07142046,0.039790463,-0.01892038,0.07674871,-0.041473687,-0.06527991,0.08924797,-0.035337735,-0.06451502,0.04719907,0.04802861,0.0059560905,-0.009271029,0.10660171,-0.052785173,-0.122866124,-0.0045048934,0.01860327,0.03996766,0.066870905,-0.002697102,-0.05259152,0.031462714,-0.08608889,-0.035629895,-0.023661833,0.08673526,-0.0488944,0.01762769,0.07211296,0.13139178,-0.016623132,-0.00014559513,0.09548968,0.04901014,0.10107639,0.06453661,0.12324707,0.07154845,-0.010187201,0.09217419,-0.0051418133,0.003002605,0.04010652,-0.027109304,0.10317594,0.00090933504,-0.051647425,0.045056507,-0.06483271,-0.032239303,0.13630095,0.08911948,0.0053133843,0.064089835,-0.011345122,0.048326097,-0.002866146,0.022620134,0.13497211,0.022119448,0.0027782216,0.00059075584,0.036154643,-0.13128361,0.057051543,0.056072716,-0.04518065,0.051704805,-0.050766625,0.024751442,0.00164576,-0.09164456,0.034157943,0.008313686,0.010849327,-0.000053701177,-0.0041490872,-0.032506954,0.0043562558,-0.02219943,-0.079818904,0.012890274,-0.0072392374,-0.011541759,-0.016119106,0.030629393,-0.1570221,-0.05596506,0.09996719,-0.012855346,0.07863743,-0.10192932,-0.04821605,-0.008208227,0.18032706,0.00071410113,-0.022193234,-0.040549606,0.021208033,0.035755675,0.040430315,0.013001211,0.16519548,0.6100601,0.037074216,-0.036974385,-0.008842286,-0.04095711,0.015469578,0.06634984,0.030303275,-0.012073043,-0.039495308,0.0822332,-0.028339557,0.1283868,-0.044975027,0.012610203,-0.047131892,-0.055342447,0.054257195,-0.021875221,-0.030637851,-0.0032359844,-0.044724785,0.049874395,-0.08957178,-0.025535796,0.0048884717,0.06450206,0.009200395,0.08204219,0.023505952,0.07955552,0.006590858,0.006104034,0.0014051019,-0.027448563,0.09859751,-0.06818036,0.08772107,-0.047244173,-0.027747001,-0.045571893,-0.023200398,0.05369473,-0.026306968,0.027328542,0.1148428,-0.024626654,0.10551738,0.05990156,-0.10536529,0.051617093,-0.02092173,-0.03830357,0.046697997,-0.008673199,0.0011671459,0.012696867,0.07912452,0.10881457,-0.027620247,0.06264698,0.045589928,-0.07203527,0.10244995,0.01139773,0.18686283,-0.04693989,-0.0074196826,0.094076544,-0.05173123,0.02027557,0.010364646,-0.005838476,-0.04829788,-0.004266676,-0.06147615,0.13027857,0.051736288,0.10414627,0.039203435,-0.043285843,-0.009600248,0.055239905,-0.02559127,0.11313175,0.021426074,0.06362182,0.021731934,0.13094318,-0.05547368,0.08233359,-0.039420635,0.18234001,-0.09558861,-0.009747496,0.011775959,0.036920052,0.04293312,0.03621745,0.053714987,0.0008069561,0.08254628,0.17628062,-0.003502362,0.0402781,-0.037845425,0.016352477,0.030367961,0.0070584207,-0.08844347,0.10918249,0.0140309585,0.06205957,0.030013196,-0.034266237,-0.054192644,0.0977929,-0.06729255,-0.042489782,-0.055442564,0.013002492,0.019094946,0.023212088,0.036400218,0.10094948,-0.002990206 ...

# %% [markdown]
# ## Interpreting A Feature

# %% [markdown]
# Let's go and investigate a non rare feature, feature 7

# %%
very_active = []

for feature_id in range(512):
    if freqs[feature_id].item() > 1e-2:
        very_active.append(feature_id)
        if len(very_active) >= 10:
            break
print(very_active)

feature_id = 9
batch_size = 50 # @param {type:"number"}

print(f"Feature freq: {freqs[feature_id].item():.4f}")
if freqs[feature_id].item() <= 1e-3:
    print("This is a rare feature!")

tokens = all_tokens[torch.randperm(len(all_tokens))[:batch_size]]
_, cache = model.run_with_cache(tokens, stop_at_layer=LAYER+1, names_filter=utils.get_act_name("post", 0))
mlp_acts = cache[utils.get_act_name("post", 0)]
print("mlp_acts shape:", mlp_acts.shape)
mlp_acts_flattened = mlp_acts.reshape(-1, cfg["d_in"])
_, hidden_acts = encoder(mlp_acts_flattened, return_mode="both")
# This is equivalent to:
# hidden_acts = F.relu((mlp_acts_flattened - encoder.b_dec) @ encoder.W_enc + encoder.b_enc)
print("hidden_acts.shape", hidden_acts.shape)

token_df = make_token_df(tokens)
token_df["feature"] = utils.to_numpy(hidden_acts[:, feature_id])
token_df.sort_values("feature", ascending=False).head(20).style.background_gradient("coolwarm")
# Out:
# [5, 13, 14, 20, 21, 24, 25, 33, 37, 38]
# Feature freq: 0.0033
# mlp_acts shape: torch.Size([50, 1024, 512])
# hidden_acts.shape torch.Size([51200, 8192])
# <style type="text/css">
# #T_6794c_row0_col3, #T_6794c_row0_col6, #T_6794c_row1_col3, #T_6794c_row1_col6, #T_6794c_row2_col3, #T_6794c_row2_col6, #T_6794c_row3_col3, #T_6794c_row3_col6, #T_6794c_row4_col3, #T_6794c_row4_col6, #T_6794c_row5_col3, #T_6794c_row5_col6, #T_6794c_row6_col3, #T_6794c_row6_col6, #T_6794c_row7_col3, #T_6794c_row7_col6, #T_6794c_row8_col3, #T_6794c_row8_col6, #T_6794c_row9_col3, #T_6794c_row9_col6, #T_6794c_row10_col3, #T_6794c_row10_col6, #T_6794c_row11_col3, #T_6794c_row11_col6, #T_6794c_row12_col3, #T_6794c_row12_col6, #T_6794c_row13_col3, #T_6794c_row13_col6, #T_6794c_row14_col3, #T_6794c_row14_col6, #T_6794c_row15_col3, #T_6794c_row15_col6, #T_6794c_row16_col3, #T_6794c_row16_col4, #T_6794c_row16_col6, #T_6794c_row17_col3, #T_6794c_row17_col6, #T_6794c_row18_col3, #T_6794c_row18_col6, #T_6794c_row19_col3, #T_6794c_row19_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6794c_row0_col4 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_6794c_row1_col4 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_6794c_row2_col4 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_6794c_row3_col4 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_6794c_row4_col4 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_6794c_row5_col4 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_6794c_row6_col4 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_6794c_row7_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6794c_row8_col4 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_6794c_row9_col4 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_6794c_row10_col4 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_6794c_row11_col4 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_6794c_row12_col4 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_6794c_row13_col4 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_6794c_row14_col4 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_6794c_row15_col4 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_6794c_row17_col4 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_6794c_row18_col4 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_6794c_row19_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6794c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6794c_level0_col0" class="col_heading level0 col0" >str_tokens</th>
#       <th id="T_6794c_level0_col1" class="col_heading level0 col1" >unique_token</th>
#       <th id="T_6794c_level0_col2" class="col_heading level0 col2" >context</th>
#       <th id="T_6794c_level0_col3" class="col_heading level0 col3" >batch</th>
#       <th id="T_6794c_level0_col4" class="col_heading level0 col4" >pos</th>
#       <th id="T_6794c_level0_col5" class="col_heading level0 col5" >label</th>
#       <th id="T_6794c_level0_col6" class="col_heading level0 col6" >feature</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6794c_level0_row0" class="row_heading level0 row0" >51160</th>
#       <td id="T_6794c_row0_col0" class="data row0 col0" >.</td>
#       <td id="T_6794c_row0_col1" class="data row0 col1" >./984</td>
#       <td id="T_6794c_row0_col2" class="data row0 col2" >·at·475,·485,·116·S.Ct|.|·2240.·Indeed,·courts·"start·with·the</td>
#       <td id="T_6794c_row0_col3" class="data row0 col3" >49</td>
#       <td id="T_6794c_row0_col4" class="data row0 col4" >984</td>
#       <td id="T_6794c_row0_col5" class="data row0 col5" >49/984</td>
#       <td id="T_6794c_row0_col6" class="data row0 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6794c_level0_row1" class="row_heading level0 row1" >51161</th>
#       <td id="T_6794c_row1_col0" class="data row1 col0" >·2</td>
#       <td id="T_6794c_row1_col1" class="data row1 col1" >·2/985</td>
#       <td id="T_6794c_row1_col2" class="data row1 col2" >·475,·485,·116·S.Ct.|·2|240.·Indeed,·courts·"start·with·the·assumption</td>
#       <td id="T_6794c_row1_col3" class="data row1 col3" >49</td>
#       <td id="T_6794c_row1_col4" class="data row1 col4" >985</td>
#       <td id="T_6794c_row1_col5" class="data row1 col5" >49/985</td>
#       <td id="T_6794c_row1_col6" class="data row1 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6794c_level0_row2" class="row_heading level0 row2" >51162</th>
#       <td id="T_6794c_row2_col0" class="data row2 col0" >240</td>
#       <td id="T_6794c_row2_col1" class="data row2 col1" >240/986</td>
#       <td id="T_6794c_row2_col2" class="data row2 col2" >,·485,·116·S.Ct.·2|240|.·Indeed,·courts·"start·with·the·assumption·that</td>
#       <td id="T_6794c_row2_col3" class="data row2 col3" >49</td>
#       <td id="T_6794c_row2_col4" class="data row2 col4" >986</td>
#       <td id="T_6794c_row2_col5" class="data row2 col5" >49/986</td>
#       <td id="T_6794c_row2_col6" class="data row2 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6794c_level0_row3" class="row_heading level0 row3" >51163</th>
#       <td id="T_6794c_row3_col0" class="data row3 col0" >.</td>
#       <td id="T_6794c_row3_col1" class="data row3 col1" >./987</td>
#       <td id="T_6794c_row3_col2" class="data row3 col2" >·485,·116·S.Ct.·2240|.|·Indeed,·courts·"start·with·the·assumption·that·the</td>
#       <td id="T_6794c_row3_col3" class="data row3 col3" >49</td>
#       <td id="T_6794c_row3_col4" class="data row3 col4" >987</td>
#       <td id="T_6794c_row3_col5" class="data row3 col5" >49/987</td>
#       <td id="T_6794c_row3_col6" class="data row3 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6794c_level0_row4" class="row_heading level0 row4" >51164</th>
#       <td id="T_6794c_row4_col0" class="data row4 col0" >·Indeed</td>
#       <td id="T_6794c_row4_col1" class="data row4 col1" >·Indeed/988</td>
#       <td id="T_6794c_row4_col2" class="data row4 col2" >5,·116·S.Ct.·2240.|·Indeed|,·courts·"start·with·the·assumption·that·the·historic</td>
#       <td id="T_6794c_row4_col3" class="data row4 col3" >49</td>
#       <td id="T_6794c_row4_col4" class="data row4 col4" >988</td>
#       <td id="T_6794c_row4_col5" class="data row4 col5" >49/988</td>
#       <td id="T_6794c_row4_col6" class="data row4 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6794c_level0_row5" class="row_heading level0 row5" >51165</th>
#       <td id="T_6794c_row5_col0" class="data row5 col0" >,</td>
#       <td id="T_6794c_row5_col1" class="data row5 col1" >,/989</td>
#       <td id="T_6794c_row5_col2" class="data row5 col2" >,·116·S.Ct.·2240.·Indeed|,|·courts·"start·with·the·assumption·that·the·historic·police</td>
#       <td id="T_6794c_row5_col3" class="data row5 col3" >49</td>
#       <td id="T_6794c_row5_col4" class="data row5 col4" >989</td>
#       <td id="T_6794c_row5_col5" class="data row5 col5" >49/989</td>
#       <td id="T_6794c_row5_col6" class="data row5 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6794c_level0_row6" class="row_heading level0 row6" >51166</th>
#       <td id="T_6794c_row6_col0" class="data row6 col0" >·courts</td>
#       <td id="T_6794c_row6_col1" class="data row6 col1" >·courts/990</td>
#       <td id="T_6794c_row6_col2" class="data row6 col2" >·116·S.Ct.·2240.·Indeed,|·courts|·"start·with·the·assumption·that·the·historic·police·powers</td>
#       <td id="T_6794c_row6_col3" class="data row6 col3" >49</td>
#       <td id="T_6794c_row6_col4" class="data row6 col4" >990</td>
#       <td id="T_6794c_row6_col5" class="data row6 col5" >49/990</td>
#       <td id="T_6794c_row6_col6" class="data row6 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6794c_level0_row7" class="row_heading level0 row7" >51167</th>
#       <td id="T_6794c_row7_col0" class="data row7 col0" >·"</td>
#       <td id="T_6794c_row7_col1" class="data row7 col1" >·"/991</td>
#       <td id="T_6794c_row7_col2" class="data row7 col2" >·S.Ct.·2240.·Indeed,·courts|·"|start·with·the·assumption·that·the·historic·police·powers·of</td>
#       <td id="T_6794c_row7_col3" class="data row7 col3" >49</td>
#       <td id="T_6794c_row7_col4" class="data row7 col4" >991</td>
#       <td id="T_6794c_row7_col5" cl

# %% [markdown]
# It's easy to misread evidence like the above, so it's useful to take some text and edit it and see how this changes the model's activations. Here's a hacky interactive tool to play around with some text.

# %%
# starting_text = "Most programming languages are easy to use, like OpenCL, OpenGL, Qt, C, etc." # @param {type:"string"}
# make_feature_vis_gradio(feature_id, starting_text)

# %% [markdown]
# A final piece of evidence: This is a one layer model, so the neurons can only matter by directly impacting the final logits! We can directly look at how the decoder weights for this feature affect the logits, and see that it boosts `'ll`! This checks out, I and he'll etc is a common construction.

# %%
# logit_effect = encoder.W_dec[feature_id] @ model.blocks[0].mlp.weight @ model.W_U
# create_vocab_df(logit_effect).head(20).style.background_gradient("coolwarm")

# %% [markdown]
# ## Manually set activation to a high value

# %%
input_text = "1,2,3,4,5"
# run the model with cache
tokens = model.to_tokens(input_text)

def activating_sae_hook(mlp_post, hook, encoder):
    mlp_post[:] = encoder(mlp_post, return_mode="sae_out", activate_feature=feature_id)
    return mlp_post

# _, cache = model.run_with_cache(tokens, stop_at_layer=LAYER+1, names_filter=utils.get_act_name("post", 0))
# mlp_acts = cache[utils.get_act_name("post", 0)]
# print("mlp_acts shape:", mlp_acts.shape)
# mlp_acts_flattened = mlp_acts.reshape(-1, cfg["d_in"])
# _, hidden_acts = encoder(mlp_acts_flattened, return_mode="both")
# manually set the feature to a high value
res_sae_activated = model.run_with_hooks(tokens, return_type="logits", fwd_hooks=[(utils.get_act_name("post", LAYER), partial(activating_sae_hook, encoder=encoder))])

# print("res_activated shape:", res_activated[-1].shape)
create_vocab_df(res_sae_activated[0][-1]).head(20).style.background_gradient("coolwarm")
# Out:
# <style type="text/css">
# #T_4a1a6_row0_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4a1a6_row1_col1 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_4a1a6_row2_col1 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_4a1a6_row3_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_4a1a6_row4_col1 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_4a1a6_row5_col1 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_4a1a6_row6_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_4a1a6_row7_col1 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_4a1a6_row8_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_4a1a6_row9_col1 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_4a1a6_row10_col1 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_4a1a6_row11_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_4a1a6_row12_col1 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_4a1a6_row13_col1, #T_4a1a6_row14_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_4a1a6_row15_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_4a1a6_row16_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_4a1a6_row17_col1, #T_4a1a6_row18_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_4a1a6_row19_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4a1a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a1a6_level0_col0" class="col_heading level0 col0" >token</th>
#       <th id="T_4a1a6_level0_col1" class="col_heading level0 col1" >logit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a1a6_level0_row0" class="row_heading level0 row0" >8379</th>
#       <td id="T_4a1a6_row0_col0" class="data row0 col0" >·sequence</td>
#       <td id="T_4a1a6_row0_col1" class="data row0 col1" >15.138222</td>
#     </tr>
#     <tr>
#       <th id="T_4a1a6_level0_row1" class="row_heading level0 row1" >16311</th>
#       <td id="T_4a1a6_row1_col0" class="data row1 col0" >·sequences</td>
#       <td id="T_4a1a6_row1_col1" class="data row1 col1" >14.341653</td>
#     </tr>
#     <tr>
#       <th id="T_4a1a6_level0_row2" class="row_heading level0 row2" >26789</th>
#       <td id="T_4a1a6_row2_col0" class="data row2 col0" >·similarity</td>
#       <td id="T_4a1a6_row2_col1" class="data row2 col1" >13.963812</td>
#     </tr>
#     <tr>
#       <th id="T_4a1a6_level0_row3" class="row_heading level0 row3" >43366</th>
#       <td id="T_4a1a6_row3_col0" class="data row3 col0" >·divergence</td>
#       <td id="T_4a1a6_row3_col1" class="data row3 col1" >12.588655</td>
#     </tr>
#     <tr>
#       <th id="T_4a1a6_level0_row4" class="row_heading level0 row4" >50250</th>
#       <td id="T_4a1a6_row4_col0" class="data row4 col0" >·amplification</td>
#       <td id="T_4a1a6_row4_col1" class="data row4 col1" >12.483156</td>
#     </tr>
#     <tr>
#       <th id="T_4a1a6_level0_row5" class="row_heading level0 row5" >19114</th>
#       <td id="T_4a1a6_row5_col0" class="data row5 col0" >·alignment</td>
#       <td id="T_4a1a6_row5_col1" class="data row5 col1" >12.312242</td>
#     </tr>
#     <tr>
#       <th id="T_4a1a6_level0_row6" class="row_heading level0 row6" >32702</th>
#       <td id="T_4a1a6_row6_col0" class="data row6 col0" >·motif</td>
#       <td id="T_4a1a6_row6_col1" class="data row6 col1" >12.234316</td>
#     </tr>
#     <tr>
#       <th id="T_4a1a6_level0_row7" class="row_heading level0 row7" >19617</th>
#       <td id="T_4a1a6_row7_col0" class="data row7 col0" >·coding</td>
#       <td id="T_4a1a6_row7_col1" class="data row7 col1" >12.124865</td>
#     </tr>
#     <tr>
#       <th id="T_4a1a6_level0_row8" class="row_heading level0 row8" >23005</th>
#       <td id="T_4a1a6_row8_col0" class="data row8 col0" >·mutations</td>
#       <td id="T_4a1a6_row8_col1" class="data row8 col1" >12.079557</td>
#     </tr>
#     <tr>
#       <th id="T_4a1a6_level0_row9" class="row_heading level0 row9" >17670</th>
#       <td id="T_4a1a6_row9_col0" class="data row9 col0" >·variants</td>
#       <td id="T_4a1a6_row9_col1" class="data row9 col1" >12.026893</td>
#     </tr>
#     <tr>
#       <th id="T_4a1a6_level0_row10" class="row_heading level0 row10" >15370</th>
#       <td id="T_4a1a6_row10_col0" class="data row10 col0" >·thereof</td>
#       <td id="T_4a1a6_row10_col1" class="data row10 col1" >11.991012</td>
#     </tr>
#     <tr>
#       <th id="T_4a1a6_level0_row11" class="row_heading level0 row11" >29819</th>
#       <td id="T_4a1a6_row11_col0" class="data row11 col0" >·repeats</td>
#       <td id="T_4a1a6_row11_col1" class="data row11 col1" >11.963839</td>
#     </tr>
#     <tr>
#       <th id="T_4a1a6_level0_row12" class="row_heading level0 row12" >20594</th>
#       <td id="T_4a1a6_row12_col0" class="data row12 col0" >·similarities</td>
#       <td id="T_4a1a6_row12_col1" class="data row12 col1" >11.840247</td>
#     </tr>
#     <tr>
#       <th id="T_4a1a6_level0_row13" class="row_heading level0 row13" >34196</th>
#       <td id="T_4a1a6_row13_col0" class="data row13 col0" >·polymorph</td>
#       <td id="T_4a1a6_row13_col1" class="data row13 col1" >11.757324</td>
#     </tr>
#     <tr>
#       <th id="T_4a1a6_level0_row14" class="row_heading level0 row14" >21004</th>
#       <td id="T_4a1a6_row14_col0" class="data row14 col0" >·encoding</td>
#       <td id="T_4a1a6_row14_col1" class="data row14 col1" >11.755597</td>
#     </tr>
#     <tr>
#       <th id="T_4a1a6_level0_row15" class="row_heading level0 row15" >286</th>
#       <td id="T_4a1a6_row15_col0" class="data row15 col0" >·of</td>
#       <td id="T_4a1a6_row15_col1" class="data row15 col1" >11.732313</td>
#     </tr>
#     <tr>
#       <th id="T_4a1a6_level0_row16" class="row_heading level0 row16" >33271</th>
#       <td id="T_4a1a6_row16_col0" class="data row16 col0" >·synonymous</td>
#       <td id="T_4a1a6_row16_col1" class="data row16 col1" >11.551994</td>
#     </tr>
#     <tr>
#       <th id="T_4a1a6_level0_row17" class="row_heading level0 row17" >30240</th>
#       <td id="T_4a1a6_row17_col0" class="data row17 col0" >·encoded</td>
#       <td id="T_4a1a6_row17_col1" class="data row17 col1" >11.480350</td>
#     </tr>
#     <tr>
#       <th id="T_4a1a6_level0_row18" class="row_heading level0 row18" >28128</th>
#       <td id="T_4a1a6_row18_col0" class="data row18 col0" >·delet</td>
#       <td id="T_4a1a6_row18_col1" class="data row18 col1" >11.477962</td>
#     </tr>
#     <tr>
#       <th id="T_4a1a6_level0_row19" class="row_heading level0 row19" >15148</th>
#       <td id="T_4a1a6_row19_col0" class="data row19 col0" >·mutation</td>
#       <td id="T_4a1a6_row19_col1" class="data row19 col1" >11.344578</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Solely CRATE

# %%
very_active = []

for feature_id in range(512):
    if freqs[feature_id].item() > 1e-2:
        very_active.append(feature_id)
        if len(very_active) >= 10:
            break
print(very_active)

feature_id = 21
batch_size = 200 # @param {type:"number"}

print(f"Feature freq: {freqs[feature_id].item():.4f}")
if freqs[feature_id].item() <= 1e-3:
    print("This is a rare feature!")

tokens = all_tokens[torch.randperm(len(all_tokens))[:batch_size]]
_, cache = model.run_with_cache(tokens, stop_at_layer=LAYER+1, names_filter=utils.get_act_name("post", 0))
mlp_acts = cache[utils.get_act_name("post", 0)]
print("mlp_acts shape:", mlp_acts.shape)
mlp_acts_flattened = mlp_acts.reshape(-1, cfg["d_in"])
# _, hidden_acts = encoder(mlp_acts_flattened, return_mode="both")
# print("hidden_acts.shape", hidden_acts.shape)

token_df = make_token_df(tokens)
token_df["feature"] = utils.to_numpy(mlp_acts_flattened[:, feature_id])
token_df.sort_values("feature", ascending=False).head(20).style.background_gradient("coolwarm")
# Out:
# [5, 13, 14, 20, 21, 24, 25, 33, 37, 38]
# Feature freq: 0.0233
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[306], line 18
#      15     print("This is a rare feature!")
#      17 tokens = all_tokens[torch.randperm(len(all_tokens))[:batch_size]]
# ---> 18 _, cache = model.run_with_cache(tokens, stop_at_layer=LAYER+1, names_filter=utils.get_act_name("post", 0))
#      19 mlp_acts = cache[utils.get_act_name("post", 0)]
#      20 print("mlp_acts shape:", mlp_acts.shape)
#
# File ~/nanogpt4crate/TransformerLens/transformer_lens/HookedTransformer.py:652, in HookedTransformer.run_with_cache(self, return_cache_object, remove_batch_dim, *model_args, **kwargs)
#     635 def run_with_cache(
#     636     self, *model_args, return_cache_object=True, remove_batch_dim=False, **kwargs
#     637 ) -> Tuple[
#    (...)
#     644     Union[ActivationCache, Dict[str, torch.Tensor]],
#     645 ]:
#     646     """Wrapper around `run_with_cache` in HookedRootModule.
#     647
#     648     If return_cache_object is True, this will return an ActivationCache object, with a bunch of
#     649     useful HookedTransformer specific methods, otherwise it will return a dictionary of
#     650     activations as in HookedRootModule.
#     651     """
# --> 652     out, cache_dict = super().run_with_cache(
#     653         *model_args, remove_batch_dim=remove_batch_dim, **kwargs
#     654     )
#     655     if return_cache_object:
#     656         cache = ActivationCache(
#     657             cache_dict, self, has_batch_dim=not remove_batch_dim
#     658         )
#
# File ~/nanogpt4crate/TransformerLens/transformer_lens/hook_points.py:467, in HookedRootModule.run_with_cache(self, names_filter, device, remove_batch_dim, incl_bwd, reset_hooks_end, clear_contexts, *model_args, **model_kwargs)
#     457 cache_dict, fwd, bwd = self.get_caching_hooks(
#     458     names_filter, incl_bwd, device, remove_batch_dim=remove_batch_dim
#     459 )
#     461 with self.hooks(
#     462     fwd_hooks=fwd,
#     463     bwd_hooks=bwd,
#     464     reset_hooks_end=reset_hooks_end,
#     465     clear_contexts=clear_contexts,
#     466 ):
# --> 467     model_out = self(*model_args, **model_kwargs)
#     468     if incl_bwd:
#     469         model_out.backward()
#
# File ~/miniconda3/envs/crate/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/crate/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/nanogpt4crate/TransformerLens/transformer_lens/HookedTransformer.py:573, in HookedTransformer.forward(self, input_ids, return_type, loss_per_token, prepend_bos, padding_side, start_at_layer, tokens, shortformer_pos_embed, attention_mask, stop_at_layer, past_kv_cache)
#     568     if shortformer_pos_embed is not None:
#     569         shortformer_pos_embed = shortformer_pos_embed.to(
#     570             devices.get_device_for_block_index(i, self.cfg)
#     571         )
# --> 573     residual = block(
#     574         residual,
#     575         # Cache contains a list of HookedTransformerKeyValueCache objects, one for each
#     576         # block
#     577         past_kv_cache_entry=past_kv_cache[i]
#     578         if past_kv_cache is not None
#     579         else None,
#     580         shortformer_pos_embed=shortformer_pos_embed,
#     581         attention_mask=attention_mask,
#     582     )  # [batch, pos, d_model]
#     584 if stop_at_layer is not None:
#     585     # When we stop at an early layer, we end here rather than doing further computation
#     586     return residual
#
# File ~/miniconda3/envs/crate/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/crate/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/nanogpt4crate/TransformerLens/transformer_lens/components.py:1482, in TransformerBlock.forward(self, resid_pre, shortformer_pos_embed, past_kv_cache_entry, attention_mask)
#    1475     key_input = attn_in
#    1476     value_input = attn_in
#    1478 attn_out = self.hook_attn_out(
#    1479     # hook the residual stream states that are used to calculate the
#    1480     # queries, keys and values, independently.
#    1481     # Then take the layer norm of these inputs, and pass these to the attention module.
# -> 1482     self.attn(
#    1483         query_input=self.ln1(query_input)
#    1484         + (0.0 if shortformer_pos_embed is None else shortformer_pos_embed),
#    1485         key_input=self.ln1(key_input)
#    1486         + (0.0 if shortformer_pos_embed is None else shortformer_pos_embed),
#    1487         value_input=self.ln1(value_input),
#    1488         past_kv_cache_entry=past_kv_cache_entry,
#    1489         attention_mask=attention_mask,
#    1490     )
#    1491 )  # [batch, pos, d_model]
#    1492 if not self.cfg.attn_only and not self.cfg.parallel_attn_mlp:
#    1493     resid_mid = self.hook_resid_mid(
#    1494         resid_pre + attn_out
#    1495     )  # [batch, pos, d_model]
#
# File ~/miniconda3/envs/crate/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/crate/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/nanogpt4crate/TransformerLens/transformer_lens/components.py:589, in AbstractAttention.forward(self, query_input, key_input, value_input, past_kv_cache_entry, additive_attention_mask, attention_mask)
#     587 attn_scores = self.hook_attn_scores(attn_scores)
#     588 pattern = F.softmax(attn_scores, dim=-1)
# --> 589 pattern = torch.where(torch.isnan(pattern), torch.zeros_like(pattern), pattern)
#     590 pattern = self.hook_pattern(pattern)  # [batch, head_index, query_pos, key_pos]
#     591 pattern = pattern.to(self.cfg.dtype)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 3.12 GiB. GPU 0 has a total capacity of 39.39 GiB of which 2.41 GiB is free. Including non-PyTorch memory, this process has 36.98 GiB memory in use. Of the allocated memory 35.01 GiB is allocated by PyTorch, and 1.48 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
input_text = "1,2,3,4,5"
# run the model with cache
tokens = model.to_tokens(input_text)

def activating_hook(mlp_post, hook, encoder):
    print("mlp_post shape:", mlp_post.shape)
    mlp_post[:, :, feature_id] = 100
    return mlp_post

# manually set the feature to a high value
res_activated = model.run_with_hooks(tokens, return_type="logits", fwd_hooks=[(utils.get_act_name("post", LAYER), partial(activating_hook, encoder=encoder))])

# print("res_activated shape:", res_activated[-1].shape)
create_vocab_df(res_activated[0][-1]).head(20).style.background_gradient("coolwarm")
# Out:
# mlp_post shape: torch.Size([1, 10, 512])
# <style type="text/css">
# #T_6375c_row0_col1, #T_6375c_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6375c_row2_col1 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_6375c_row3_col1 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_6375c_row4_col1 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_6375c_row5_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_6375c_row6_col1 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_6375c_row7_col1 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_6375c_row8_col1 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_6375c_row9_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_6375c_row10_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_6375c_row11_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_6375c_row12_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_6375c_row13_col1, #T_6375c_row14_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_6375c_row15_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_6375c_row16_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_6375c_row17_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_6375c_row18_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_6375c_row19_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6375c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6375c_level0_col0" class="col_heading level0 col0" >token</th>
#       <th id="T_6375c_level0_col1" class="col_heading level0 col1" >logit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6375c_level0_row0" class="row_heading level0 row0" >30109</th>
#       <td id="T_6375c_row0_col0" class="data row0 col0" >[[</td>
#       <td id="T_6375c_row0_col1" class="data row0 col1" >14.789650</td>
#     </tr>
#     <tr>
#       <th id="T_6375c_level0_row1" class="row_heading level0 row1" >198</th>
#       <td id="T_6375c_row1_col0" class="data row1 col0" >↩
# </td>
#       <td id="T_6375c_row1_col1" class="data row1 col1" >14.781439</td>
#     </tr>
#     <tr>
#       <th id="T_6375c_level0_row2" class="row_heading level0 row2" >58</th>
#       <td id="T_6375c_row2_col0" class="data row2 col0" >[</td>
#       <td id="T_6375c_row2_col1" class="data row2 col1" >13.484408</td>
#     </tr>
#     <tr>
#       <th id="T_6375c_level0_row3" class="row_heading level0 row3" >220</th>
#       <td id="T_6375c_row3_col0" class="data row3 col0" >·</td>
#       <td id="T_6375c_row3_col1" class="data row3 col1" >12.952336</td>
#     </tr>
#     <tr>
#       <th id="T_6375c_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_6375c_row4_col0" class="data row4 col0" >#</td>
#       <td id="T_6375c_row4_col1" class="data row4 col1" >12.803120</td>
#     </tr>
#     <tr>
#       <th id="T_6375c_level0_row5" class="row_heading level0 row5" >23428</th>
#       <td id="T_6375c_row5_col0" class="data row5 col0" >VAL</td>
#       <td id="T_6375c_row5_col1" class="data row5 col1" >11.601645</td>
#     </tr>
#     <tr>
#       <th id="T_6375c_level0_row6" class="row_heading level0 row6" >9792</th>
#       <td id="T_6375c_row6_col0" class="data row6 col0" >FT</td>
#       <td id="T_6375c_row6_col1" class="data row6 col1" >10.868013</td>
#     </tr>
#     <tr>
#       <th id="T_6375c_level0_row7" class="row_heading level0 row7" >5420</th>
#       <td id="T_6375c_row7_col0" class="data row7 col0" >ref</td>
#       <td id="T_6375c_row7_col1" class="data row7 col1" >10.781559</td>
#     </tr>
#     <tr>
#       <th id="T_6375c_level0_row8" class="row_heading level0 row8" >7753</th>
#       <td id="T_6375c_row8_col0" class="data row8 col0" >file</td>
#       <td id="T_6375c_row8_col1" class="data row8 col1" >10.532041</td>
#     </tr>
#     <tr>
#       <th id="T_6375c_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_6375c_row9_col0" class="data row9 col0" >-</td>
#       <td id="T_6375c_row9_col1" class="data row9 col1" >10.437276</td>
#     </tr>
#     <tr>
#       <th id="T_6375c_level0_row10" class="row_heading level0 row10" >0</th>
#       <td id="T_6375c_row10_col0" class="data row10 col0" >!</td>
#       <td id="T_6375c_row10_col1" class="data row10 col1" >10.284873</td>
#     </tr>
#     <tr>
#       <th id="T_6375c_level0_row11" class="row_heading level0 row11" >27</th>
#       <td id="T_6375c_row11_col0" class="data row11 col0" ><</td>
#       <td id="T_6375c_row11_col1" class="data row11 col1" >10.233631</td>
#     </tr>
#     <tr>
#       <th id="T_6375c_level0_row12" class="row_heading level0 row12" >38</th>
#       <td id="T_6375c_row12_col0" class="data row12 col0" >G</td>
#       <td id="T_6375c_row12_col1" class="data row12 col1" >10.205491</td>
#     </tr>
#     <tr>
#       <th id="T_6375c_level0_row13" class="row_heading level0 row13" >66</th>
#       <td id="T_6375c_row13_col0" class="data row13 col0" >c</td>
#       <td id="T_6375c_row13_col1" class="data row13 col1" >10.170671</td>
#     </tr>
#     <tr>
#       <th id="T_6375c_level0_row14" class="row_heading level0 row14" >41634</th>
#       <td id="T_6375c_row14_col0" class="data row14 col0" >aligned</td>
#       <td id="T_6375c_row14_col1" class="data row14 col1" >10.160979</td>
#     </tr>
#     <tr>
#       <th id="T_6375c_level0_row15" class="row_heading level0 row15" >48</th>
#       <td id="T_6375c_row15_col0" class="data row15 col0" >Q</td>
#       <td id="T_6375c_row15_col1" class="data row15 col1" >10.131870</td>
#     </tr>
#     <tr>
#       <th id="T_6375c_level0_row16" class="row_heading level0 row16" >33</th>
#       <td id="T_6375c_row16_col0" class="data row16 col0" >B</td>
#       <td id="T_6375c_row16_col1" class="data row16 col1" >10.080691</td>
#     </tr>
#     <tr>
#       <th id="T_6375c_level0_row17" class="row_heading level0 row17" >22897</th>
#       <td id="T_6375c_row17_col0" class="data row17 col0" >document</td>
#       <td id="T_6375c_row17_col1" class="data row17 col1" >9.941419</td>
#     </tr>
#     <tr>
#       <th id="T_6375c_level0_row18" class="row_heading level0 row18" >26495</th>
#       <td id="T_6375c_row18_col0" class="data row18 col0" >package</td>
#       <td id="T_6375c_row18_col1" class="data row18 col1" >9.909563</td>
#     </tr>
#     <tr>
#       <th id="T_6375c_level0_row19" class="row_heading level0 row19" >2209</th>
#       <td id="T_6375c_row19_col0" class="data row19 col0" >·address</td>
#       <td id="T_6375c_row19_col1" class="data row19 col1" >9.888938</td>
#     </tr>
#   </tbody>
# </table>
